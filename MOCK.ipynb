# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
fileloc = 'C:/Users/subro/Downloads/MOCK_DATA.csv'
mfile = pd.read_csv(fileloc)

# %%
print(mfile.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          1000 non-null   int64
#  1   FIRST NAME  1000 non-null   object
#  2   LAST NAME   1000 non-null   object
#  3   email       943 non-null    object
#  4   gender      1000 non-null   object
#  5   ENGLISH     1000 non-null   int64
#  6   SCIENCE     1000 non-null   int64
#  7   MATHS       1000 non-null   int64
#  8   HINDI       1000 non-null   int64
#  9   COMPUTER    1000 non-null   int64
# dtypes: int64(6), object(4)
# memory usage: 78.3+ KB
# None

# %%
mfile
# Out:
#        ID FIRST NAME  LAST NAME                       email    gender  \
# 0       1        Eba     Felten    efelten0@theguardian.com    Female
# 1       2       Herb     Witton                         NaN      Male
# 2       3     Gasper  Buckhurst                         NaN      Male
# 3       4     Martha       Iron       miron3@friendfeed.com    Female
# 4       5     Vickie   Pethrick  vpethrick4@kickstarter.com  Bigender
# ..    ...        ...        ...                         ...       ...
# 995   996     Lorita    Poluzzi  lpoluzzirn@kickstarter.com    Female
# 996   997        Fax      Kynnd                         NaN      Male
# 997   998     Moises     Bessom      mbessomrp@mashable.com      Male
# 998   999      Keary     Allatt        kallattrq@apache.org      Male
# 999  1000   Lauretta    McCrory    lmccroryrr@canalblog.com    Female
#
#      ENGLISH  SCIENCE  MATHS  HINDI  COMPUTER
# 0         80       41     86     84        98
# ...

# %%
print(mfile)
# Out:
#        ID FIRST NAME  LAST NAME                       email    gender  \
# 0       1        Eba     Felten    efelten0@theguardian.com    Female
# 1       2       Herb     Witton                         NaN      Male
# 2       3     Gasper  Buckhurst                         NaN      Male
# 3       4     Martha       Iron       miron3@friendfeed.com    Female
# 4       5     Vickie   Pethrick  vpethrick4@kickstarter.com  Bigender
# ..    ...        ...        ...                         ...       ...
# 995   996     Lorita    Poluzzi  lpoluzzirn@kickstarter.com    Female
# 996   997        Fax      Kynnd                         NaN      Male
# 997   998     Moises     Bessom      mbessomrp@mashable.com      Male
# 998   999      Keary     Allatt        kallattrq@apache.org      Male
# 999  1000   Lauretta    McCrory    lmccroryrr@canalblog.com    Female
#
#      ENGLISH  SCIENCE  MATHS  HINDI  COMPUTER
# 0         80       41     86     84        98
# ...

# %%
mfile.head()
# Out:
#    ID FIRST NAME  LAST NAME                       email    gender  ENGLISH  \
# 0   1        Eba     Felten    efelten0@theguardian.com    Female       80
# 1   2       Herb     Witton                         NaN      Male       77
# 2   3     Gasper  Buckhurst                         NaN      Male       39
# 3   4     Martha       Iron       miron3@friendfeed.com    Female       34
# 4   5     Vickie   Pethrick  vpethrick4@kickstarter.com  Bigender       33
#
#    SCIENCE  MATHS  HINDI  COMPUTER
# 0       41     86     84        98
# 1       96     76     42        57
# 2       74     36     86        74
# 3       87     48     56        68
# 4       59     33     93        93

# %%
print(mfile.head())
# Out:
#    ID FIRST NAME  LAST NAME                       email    gender  ENGLISH  \
# 0   1        Eba     Felten    efelten0@theguardian.com    Female       80
# 1   2       Herb     Witton                         NaN      Male       77
# 2   3     Gasper  Buckhurst                         NaN      Male       39
# 3   4     Martha       Iron       miron3@friendfeed.com    Female       34
# 4   5     Vickie   Pethrick  vpethrick4@kickstarter.com  Bigender       33
#
#    SCIENCE  MATHS  HINDI  COMPUTER
# 0       41     86     84        98
# 1       96     76     42        57
# 2       74     36     86        74
# 3       87     48     56        68
# 4       59     33     93        93

# %%
mfile.tail()
# Out:
#        ID FIRST NAME LAST NAME                       email  gender  ENGLISH  \
# 995   996     Lorita   Poluzzi  lpoluzzirn@kickstarter.com  Female       92
# 996   997        Fax     Kynnd                         NaN    Male       90
# 997   998     Moises    Bessom      mbessomrp@mashable.com    Male       76
# 998   999      Keary    Allatt        kallattrq@apache.org    Male       80
# 999  1000   Lauretta   McCrory    lmccroryrr@canalblog.com  Female       69
#
#      SCIENCE  MATHS  HINDI  COMPUTER
# 995       67     44     50        84
# 996       99     48     64        62
# 997       45     71     36        89
# 998       73     63     30        43
# 999       34     70     45        91

# %%
mfile.head(15)
# Out:
#     ID FIRST NAME    LAST NAME                            email    gender  \
# 0    1        Eba       Felten         efelten0@theguardian.com    Female
# 1    2       Herb       Witton                              NaN      Male
# 2    3     Gasper    Buckhurst                              NaN      Male
# 3    4     Martha         Iron            miron3@friendfeed.com    Female
# 4    5     Vickie     Pethrick       vpethrick4@kickstarter.com  Bigender
# 5    6        Any     Pringley            apringley5@usnews.com      Male
# 6    7      Dulci   Collacombe        dcollacombe6@multiply.com    Female
# 7    8       Vito         Koch               vkoch7@arizona.edu      Male
# 8    9       Cris      Hellard          chellard8@bloomberg.com      Male
# 9   10     Ashely   Pinckstone         apinckstone9@nbcnews.com    Female
# 10  11        Ree  MacKettrick  rmackettricka@howstuffworks.com   Agender
# 11  12      Clint      Dannohl       cdannohlb@chronoengine.com      Male
# ...

# %%
print(mfile.isnull().sum())
# Out:
# ID             0
# FIRST NAME     0
# LAST NAME      0
# email         57
# gender         0
# ENGLISH        0
# SCIENCE        0
# MATHS          0
# HINDI          0
# COMPUTER       0
# dtype: int64

# %%
mfile = mfile.dropna()

# %%
print(mfile.isnull().sum())
# Out:
# ID            0
# FIRST NAME    0
# LAST NAME     0
# email         0
# gender        0
# ENGLISH       0
# SCIENCE       0
# MATHS         0
# HINDI         0
# COMPUTER      0
# dtype: int64

# %%
print(mfile.duplicated().sum())
# Out:
# 0

# %%
print(mfile.describe())
# Out:
#                 ID     ENGLISH     SCIENCE       MATHS       HINDI    COMPUTER
# count   943.000000  943.000000  943.000000  943.000000  943.000000  943.000000
# mean    496.032874   64.606575   64.394486   65.021209   64.935313   63.866384
# std     286.919158   20.518881   20.580463   20.232292   20.363758   20.808937
# min       1.000000   30.000000   30.000000   30.000000   30.000000   30.000000
# 25%     246.500000   46.000000   46.500000   47.500000   47.000000   46.000000
# 50%     494.000000   64.000000   65.000000   65.000000   65.000000   63.000000
# 75%     742.500000   82.000000   81.500000   82.000000   83.000000   82.000000
# max    1000.000000  100.000000  100.000000  100.000000  100.000000  100.000000

# %%
print(mfile.columns)
# Out:
# Index(['ID', 'FIRST NAME', 'LAST NAME', 'email', 'gender', 'ENGLISH',
#        'SCIENCE', 'MATHS', 'HINDI', 'COMPUTER'],
#       dtype='object')

# %%
toteng = mfile['ENGLISH'].value_counts()
toteng.plot(kind='barh', color=sns.color_palette("Spectral", len(toteng)))
plt.title('RANKS IN ENGLISH')
plt.xlabel('SCORE IN ENGLISH')
plt.show()

# %%
plt.figure(figsize=(12, 10))
toteng = mfile['ENGLISH'].value_counts()
topeng = toteng.head(20)
topeng.plot(kind='barh', color=sns.color_palette("Spectral", len(toteng)))
plt.title('TOP SCORER IN ENGLISH')
plt.xlabel('SCORER IN ENGLISH', fontsize=14)
plt.ylabel('SCORE', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()
